# %%
import tensorflow as tf
import numpy as np
import random

# %%
def make_mini_batch(train_data, size_of_mini_batch, length_of_sequences):
    inputs  = np.empty(0)
    outputs = np.empty(0)
    for _ in range(size_of_mini_batch):
        index   = random.randint(0, len(train_data) - length_of_sequences)
        part    = train_data[index:index + length_of_sequences]
        inputs  = np.append(inputs, part[:, 0])
        outputs = np.append(outputs, part[-1, 1])
    inputs  = inputs.reshape(-1, length_of_sequences, 1)
    outputs = outputs.reshape(-1, 1)
    return (inputs, outputs)

# %%
def make_prediction_initial(train_data, index, length_of_sequences):
    return train_data[index:index + length_of_sequences, 0]

# %%
train_data_path             = "./normal.npy"
num_of_input_nodes          = 1
num_of_hidden_nodes         = 2
num_of_output_nodes         = 1
length_of_sequences         = 50
num_of_training_epochs      = 800
length_of_initial_sequences = 50
num_of_prediction_epochs    = 100
size_of_mini_batch          = 100
learning_rate               = 0.1
forget_bias                 = 1.0
print("train_data_path             = %s" % train_data_path)
print("num_of_input_nodes          = %d" % num_of_input_nodes)
print("num_of_hidden_nodes         = %d" % num_of_hidden_nodes)
print("num_of_output_nodes         = %d" % num_of_output_nodes)
print("length_of_sequences         = %d" % length_of_sequences)
print("num_of_training_epochs      = %d" % num_of_training_epochs)
print("length_of_initial_sequences = %d" % length_of_initial_sequences)
print("num_of_prediction_epochs    = %d" % num_of_prediction_epochs)
print("size_of_mini_batch          = %d" % size_of_mini_batch)
print("learning_rate               = %f" % learning_rate)
print("forget_bias                 = %f" % forget_bias)
# Out:
# train_data_path             = ./normal.npy
# num_of_input_nodes          = 1
# num_of_hidden_nodes         = 2
# num_of_output_nodes         = 1
# length_of_sequences         = 50
# num_of_training_epochs      = 2000
# length_of_initial_sequences = 50
# num_of_prediction_epochs    = 100
# size_of_mini_batch          = 100
# learning_rate               = 0.100000
# forget_bias                 = 1.000000

# %%
train_data = np.load(train_data_path)
print("train_data:", train_data)
# Out:
# ('train_data:', array([[  0.00000000e+00,   1.25333234e-01],
#        [  1.25333234e-01,   2.48689887e-01],
#        [  2.48689887e-01,   3.68124553e-01],
#        ...,
#        [ -3.68124553e-01,  -2.48689887e-01],
#        [ -2.48689887e-01,  -1.25333234e-01],
#        [ -1.25333234e-01,   3.92877345e-15]]))

# %%
# random seed fix
random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)

# %%
with tf.Graph().as_default():
    input_ph      = tf.placeholder(tf.float32, [None, length_of_sequences, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, num_of_output_nodes], name="supervisor")
    istate_ph     = tf.placeholder(tf.float32, [None, num_of_hidden_nodes * 2], name="istate")

    with tf.name_scope("inference") as scope:
        weight1_var = tf.Variable(tf.truncated_normal([num_of_input_nodes, num_of_hidden_nodes], stddev=0.1), name="weight1")
        weight2_var = tf.Variable(tf.truncated_normal([num_of_hidden_nodes, num_of_output_nodes], stddev=0.1), name="weight2")
        bias1_var   = tf.Variable(tf.truncated_normal([num_of_hidden_nodes], stddev=0.1), name="bias1")
        bias2_var   = tf.Variable(tf.truncated_normal([num_of_output_nodes], stddev=0.1), name="bias2")

        in1 = tf.transpose(input_ph, [1, 0, 2])         # (batch, sequence, data) -> (sequence, batch, data)
        in2 = tf.reshape(in1, [-1, num_of_input_nodes]) # (sequence, batch, data) -> (sequence * batch, data)
        in3 = tf.matmul(in2, weight1_var) + bias1_var
        in4 = tf.split(0, length_of_sequences, in3)     # sequence * (batch, data)

        cell = tf.nn.rnn_cell.BasicLSTMCell(num_of_hidden_nodes, forget_bias=forget_bias)
        rnn_output, states_op = tf.nn.rnn(cell, in4, initial_state=istate_ph)
        output_op = tf.matmul(rnn_output[-1], weight2_var) + bias2_var

    with tf.name_scope("loss") as scope:
        square_error = tf.reduce_mean(tf.square(output_op - supervisor_ph))
        loss_op      = square_error
        tf.scalar_summary("loss", loss_op)

    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("data", graph=sess.graph)
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = make_mini_batch(train_data, size_of_mini_batch, length_of_sequences)

            train_dict = {
                input_ph:      inputs,
                supervisor_ph: supervisors,
                istate_ph:     np.zeros((size_of_mini_batch, num_of_hidden_nodes * 2)),
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch + 1) % 10 == 0:
                summary_str, train_loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                summary_writer.add_summary(summary_str, epoch)
                print("train#%d, train loss: %e" % (epoch + 1, train_loss))

        inputs  = make_prediction_initial(train_data, 0, length_of_initial_sequences)
        outputs = np.empty(0)
        states  = np.zeros((num_of_hidden_nodes * 2)),

        print("initial:", inputs)
        np.save("initial.npy", inputs)

        for epoch in range(num_of_prediction_epochs):
            pred_dict = {
                input_ph:  inputs.reshape((1, length_of_sequences, 1)),
                istate_ph: states,
            }
            output, states = sess.run([output_op, states_op], feed_dict=pred_dict)
            print("prediction#%d, output: %f" % (epoch + 1, output))

            inputs  = np.delete(inputs, 0)
            inputs  = np.append(inputs, output)
            outputs = np.append(outputs, output)

        print("outputs:", outputs)
        np.save("output.npy", outputs)

        saver.save(sess, "data/model")
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7f3df3aef3d0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# train#10, train loss: 4.538865e-01
# train#20, train loss: 4.490439e-01
# train#30, train loss: 3.819196e-01
# train#40, train loss: 2.568893e-01
# train#50, train loss: 1.888629e-01
# train#60, train loss: 9.913924e-02
# train#70, train loss: 5.205063e-02
# train#80, train loss: 2.581991e-02
# train#90, train loss: 2.036129e-02
# train#100, train loss: 1.831731e-02
# train#110, train loss: 1.271619e-02
# train#120, train loss: 1.229325e-02
# train#130, train loss: 1.083356e-02
# train#140, train loss: 1.279502e-02
# train#150, train loss: 1.287019e-02
# train#160, train loss: 1.099299e-02
# train#170, train loss: 1.007394e-02
# train#180, train loss: 9.447766e-03
# train#190, train loss: 9.763908e-03
# train#200, train loss: 8.208628e-03
# train#210, train loss: 8.803483e-03
# train#220, train loss: 7.980088e-03
# train#230, train loss: 7.584600e-03
# train#240, train loss: 6.741407e-03
# train#250, train loss: 7.071269e-03
# train#260, train loss: 6.850915e-03
# train#270, train loss: 6.787790e-03
# train#280, train loss: 6.316117e-03
# train#290, train loss: 6.913977e-03
# train#300, train loss: 6.453085e-03
# train#310, train loss: 5.325700e-03
#          3.68124553e-01,   4.81753674e-01,   5.87785252e-01,
#          6.84547106e-01,   7.70513243e-01,   8.44327926e-01,
#          9.04827052e-01,   9.51056516e-01,   9.82287251e-01,
#          9.98026728e-01,   9.98026728e-01,   9.82287251e-01,
#          9.51056516e-01,   9.04827052e-01,   8.44327926e-01,
#          7.70513243e-01,   6.84547106e-01,   5.87785252e-01,
#          4.81753674e-01,   3.68124553e-01,   2.48689887e-01,
#          1.25333234e-01,  -3.21624530e-16,  -1.25333234e-01,
#         -2.48689887e-01,  -3.68124553e-01,  -4.81753674e-01,
#         -5.87785252e-01,  -6.84547106e-01,  -7.70513243e-01,
#         -8.44327926e-01,  -9.04827052e-01,  -9.51056516e-01,
#         -9.82287251e-01,  -9.98026728e-01,  -9.98026728e-01,
#         -9.82287251e-01,  -9.51056516e-01,  -9.04827052e-01,
#         -8.44327926e-01,  -7.70513243e-01,  -6.84547106e-01,
#         -5.87785252e-01,  -4.81753674e-01,  -3.68124553e-01,
#         -2.48689887e-01,  -1.25333234e-01]))
# prediction#1, output: 0.037360
# prediction#2, output: 0.187522
# prediction#3, output: 0.335662
# prediction#4, output: 0.475685
# prediction#5, output: 0.602218
# prediction#6, output: 0.711631
# prediction#7, output: 0.802388
# prediction#8, output: 0.874740
# prediction#9, output: 0.930091
# prediction#10, output: 0.970354
# prediction#11, output: 0.997487
# prediction#12, output: 1.013211
# prediction#13, output: 1.018876
# prediction#14, output: 1.015408
# prediction#15, output: 1.003293
# prediction#16, output: 0.982571
# prediction#17, output: 0.952830
# prediction#18, output: 0.913191
# prediction#19, output: 0.862324
# prediction#20, output: 0.798522
# prediction#21, output: 0.719953
# prediction#22, output: 0.625228
# prediction#23, output: 0.514342
# prediction#24, output: 0.389739
# prediction#25, output: 0.256577
# prediction#26, output: 0.121263
# prediction#27, output: -0.011169
# prediction#28, output: -0.138605
# prediction#29, output: -0.261126
# prediction#30, output: -0.379124
# prediction#31, output: -0.491901
# prediction#32, output: -0.597370
# prediction#33, output: -0.692619
# prediction#34, output: -0.774817
# prediction#35, output: -0.841956
# prediction#36, output: -0.893178
# prediction#37, output: -0.928684
# prediction#38, output: -0.949398
# prediction#39, output: -0.956585
# prediction#40, output: -0.951544
# prediction#41, output: -0.935415
# prediction#42, output: -0.909083
# prediction#43, output: -0.873146
# prediction#44, output: -0.827919
# prediction#45, output: -0.773470
# prediction#46, output: -0.709662
# prediction#47, output: -0.636223
# prediction#48, output: -0.552839
# prediction#49, output: -0.459301
# prediction#50, output: -0.355695
# prediction#51, output: -0.242659
# prediction#52, output: -0.121659
# prediction#53, output: 0.004795
# prediction#54, output: 0.133101
# prediction#55, output: 0.258830
# prediction#56, output: 0.377308
# prediction#57, output: 0.484357
# prediction#58, output: 0.576908
# prediction#59, output: 0.653254
# prediction#60, output: 0.712921
# prediction#61, output: 0.756284
# prediction#62, output: 0.784128
# prediction#63, output: 0.797277
# prediction#64, output: 0.796324
# prediction#65, output: 0.781475
# prediction#66, output: 0.752478
# prediction#67, output: 0.708647
# prediction#68, output: 0.649033
# prediction#69, output: 0.572809
# prediction#70, output: 0.479929
# prediction#71, output: 0.371942
# prediction#72, output: 0.252485
# prediction#73, output: 0.126754
# prediction#74, output: -0.000110
# prediction#75, output: -0.124591
# prediction#76, output: -0.245046
# prediction#77, output: -0.360713
# prediction#78, output: -0.470560
# prediction#79, output: -0.572768
# prediction#80, output: -0.664948
# prediction#81, output: -0.744738
# prediction#82, output: -0.810389
# prediction#83, output: -0.861069
# prediction#84, output: -0.896838
# prediction#85, output: -0.918411
# prediction#86, output: -0.926845
# prediction#87, output: -0.923276
# prediction#88, output: -0.908735
# prediction#89, output: -0.884048
# prediction#90, output: -0.849796
# prediction#91, output: -0.806310
# prediction#92, output: -0.753705
# prediction#93, output: -0.691915
# prediction#94, output: -0.620762
# prediction#95, output: -0.540050
# prediction#96, output: -0.449704
# prediction#97, output: -0.349944
# prediction#98, output: -0.241520
# prediction#99, output: -0.125942
# prediction#100, output: -0.005663
# ('outputs:', array([  3.73597592e-02,   1.87522367e-01,   3.35661590e-01,
#          4.75684702e-01,   6.02217674e-01,   7.11630881e-01,
#          8.02387595e-01,   8.74739945e-01,   9.30090904e-01,
#          9.70354378e-01,   9.97487247e-01,   1.01321101e+00,
#          1.01887608e+00,   1.01540804e+00,   1.00329292e+00,
#          9.82571185e-01,   9.52829778e-01,   9.13191497e-01,
#          8.62324357e-01,   7.98521698e-01,   7.19953299e-01,
#          6.25228107e-01,   5.14342427e-01,   3.89738977e-01,
#          2.56576657e-01,   1.21262714e-01,  -1.11687630e-02,
#         -1.38605192e-01,  -2.61126041e-01,  -3.79123986e-01,
#         -4.91901278e-01,  -5.97369850e-01,  -6.92619324e-01,
#         -7.74817169e-01,  -8.41955602e-01,  -8.93177688e-01,
#         -9.28683937e-01,  -9.49398339e-01,  -9.56585228e-01,
#         -9.51543987e-01,  -9.35415208e-01,  -9.09083426e-01,
#         -8.73145521e-01,  -8.27918947e-01,  -7.73470104e-01,
#         -7.09662378e-01,  -6.36222959e-01,  -5.52839220e-01,
#         -4.59300637e-01,  -3.55694711e-01,  -2.42659166e-01,
#         -1.21658549e-01,   4.79507446e-03,   1.33100569e-01,
#          2.58829683e-01,   3.77308309e-01,   4.84357476e-01,
#          5.76907694e-01,   6.53253853e-01,   7.12921023e-01,
#          7.56283998e-01,   7.84128308e-01,   7.97276735e-01,
#          7.96323836e-01,   7.81475365e-01,   7.52478123e-01,
#          7.08646894e-01,   6.49033129e-01,   5.72809339e-01,
#          4.79928970e-01,   3.71941864e-01,   2.52484918e-01,
#          1.26754299e-01,  -1.09925866e-04,  -1.24591127e-01,
#         -2.45045677e-01,  -3.60712826e-01,  -4.70559657e-01,
#         -5.72768271e-01,  -6.64947987e-01,  -7.44737804e-01,
#         -8.10388982e-01,  -8.61068785e-01,  -8.96838129e-01,
#         -9.18410838e-01,  -9.26844656e-01,  -9.23275769e-01,
#         -9.08734977e-01,  -8.84048402e-01,  -8.49795520e-01,
#         -8.06310475e-01,  -7.53705442e-01,  -6.91915154e-01,
#         -6.20761693e-01,  -5.40050328e-01,  -4.49703693e-01,
#         -3.49944174e-01,  -2.41520032e-01,  -1.25942364e-01,
#         -5.66332042e-03]))
